# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## a)

# %% [markdown]
# ## b)

# %% [markdown]
# ## c)

# %% [markdown]
# ## d)

# %% [markdown]
# ## e)

# %% [markdown]
# ## f)

# %% [markdown]
# ## g)

# %% [markdown]
# ## h)

# %% [markdown]
# ## i)

# %% [markdown]
# ## j)
